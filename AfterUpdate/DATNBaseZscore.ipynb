# %% [markdown]
# - Đọc data
# - Xử lý clean data, oulier
# - Chia train, test
# - Scale data
# - Train

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/DATN/fetal_health.csv'
data = pd.read_csv(file_path)
display(data.head())
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
#  8   mean_value_of_short_term_variability                    2126 non-null   float64
#  9   percentage_of_time_with_abnormal_long_term_variability  2126 non-null   float64
#  10  mean_value_of_long_term_variability                     2126 non-null   float64
#  11  histogram_width                                         2126 non-null   float64
#  12  histogram_min                                           2126 non-null   float64
#  13  histogram_max                                           2126 non-null   float64
#  14  histogram_number_of_peaks                               2126 non-null   float64
#  15  histogram_number_of_zeroes                              2126 non-null   float64
#  16  histogram_mode                                          2126 non-null   float64
#  17  histogram_mean                                          2126 non-null   float64
#  18  histogram_median                                        2126 non-null   float64
#  19  histogram_variance                                      2126 non-null   float64
#  20  histogram_tendency                                      2126 non-null   float64
#  21  fetal_health                                            2126 non-null   float64
# dtypes: float64(22)
# memory usage: 365.5 KB

# %%
data.shape
# Out:
# (2126, 22)

# %%
data.duplicated().sum()
# Out:
# np.int64(13)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# =============================
# Xử lý giá trị thiếu

print("Kích thước dữ liệu sau khi xoá duplicate:", data.shape)

# Kiểm tra số lượng giá trị thiếu trên từng cột
missing_values = data.isna().sum()
missing_percent = (data.isna().sum() / len(data)) * 100

missing_table = pd.DataFrame({
    "Số lượng giá trị thiếu": missing_values,
    "Tỷ lệ thiếu (%)": missing_percent
})

print("Bảng kiểm tra giá trị thiếu:")
display(missing_table)

# Tổng số giá trị thiếu trong toàn bộ dữ liệu
total_missing = data.isna().sum().sum()
print("Tổng số giá trị thiếu trong dữ liệu:", total_missing)


if total_missing > 0:
    target_col = "fetal_health"

    # Nếu cột đầu ra bị thiếu thì xoá dòng đó
    if data[target_col].isna().sum() > 0:
        print(f"Số giá trị thiếu ở biến mục tiêu {target_col}: {data[target_col].isna().sum()}")
        data = data.dropna(subset=[target_col])
        print("Đã xoá các dòng bị thiếu ở biến mục tiêu.")

    # Lấy các cột số, ngoại trừ biến mục tiêu
    num_cols = data.select_dtypes(include=["int64", "float64"]).columns
    num_cols = [col for col in num_cols if col != target_col]

    # Thay giá trị thiếu của các cột số bằng median
    for col in num_cols:
        if data[col].isna().sum() > 0:
            median_value = data[col].median()
            data[col] = data[col].fillna(median_value)
            print(f"Đã thay giá trị thiếu ở cột {col} bằng median = {median_value}")

else:
    print("Dữ liệu không có giá trị thiếu, không cần xử lý.")

# Reset index sau khi xử lý
data = data.reset_index(drop=True)

# Kiểm tra lại sau xử lý
print("\nTổng số giá trị thiếu sau xử lý:", data.isna().sum().sum())
print("Kích thước dữ liệu sau xử lý giá trị thiếu:", data.shape)

display(data.head())
# Out:
# Kích thước dữ liệu sau khi xoá duplicate: (2113, 22)
# Bảng kiểm tra giá trị thiếu:
#                                                     Số lượng giá trị thiếu  \
# baseline value                                                           0
# accelerations                                                            0
# fetal_movement                                                           0
# uterine_contractions                                                     0
# light_decelerations                                                      0
# severe_decelerations                                                     0
# prolongued_decelerations                                                 0
# abnormal_short_term_variability                                          0
# mean_value_of_short_term_variability                                     0
# percentage_of_time_with_abnormal_long_term_vari...                       0
# mean_value_of_long_term_variability                                      0
# histogram_width                                                          0
# histogram_min                                                            0
# histogram_max                                                            0
# histogram_number_of_peaks                                                0
# histogram_number_of_zeroes                                               0
# histogram_mode                                                           0
# histogram_mean                                                           0
# histogram_median                                                         0
# histogram_variance                                                       0
# histogram_tendency                                                       0
# fetal_health                                                             0
#
#                                                     Tỷ lệ thiếu (%)
# baseline value                                                  0.0
# accelerations                                                   0.0
# fetal_movement                                                  0.0
# uterine_contractions                                            0.0
# light_decelerations                                             0.0
# severe_decelerations                                            0.0
# prolongued_decelerations                                        0.0
# abnormal_short_term_variability                                 0.0
# mean_value_of_short_term_variability                            0.0
# percentage_of_time_with_abnormal_long_term_vari...              0.0
# mean_value_of_long_term_variability                             0.0
# histogram_width                                                 0.0
# histogram_min                                                   0.0
# histogram_max                                                   0.0
# histogram_number_of_peaks                                       0.0
# histogram_number_of_zeroes                                      0.0
# histogram_mode                                                  0.0
# histogram_mean                                                  0.0
# histogram_median                                                0.0
# histogram_variance                                              0.0
# histogram_tendency                                              0.0
# fetal_health                                                    0.0
# Tổng số giá trị thiếu trong dữ liệu: 0
# Dữ liệu không có giá trị thiếu, không cần xử lý.
#
# Tổng số giá trị thiếu sau xử lý: 0
# Kích thước dữ liệu sau xử lý giá trị thiếu: (2113, 22)
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
data.describe().T
# Out:
#                                                      count        mean  \
# baseline value                                      2113.0  133.304780
# accelerations                                       2113.0    0.003188
# fetal_movement                                      2113.0    0.009517
# uterine_contractions                                2113.0    0.004387
# light_decelerations                                 2113.0    0.001901
# severe_decelerations                                2113.0    0.000003
# prolongued_decelerations                            2113.0    0.000159
# abnormal_short_term_variability                     2113.0   46.993848
# mean_value_of_short_term_variability                2113.0    1.335021
# percentage_of_time_with_abnormal_long_term_vari...  2113.0    9.795078
# mean_value_of_long_term_variability                 2113.0    8.166635
# histogram_width                                     2113.0   70.535258
# histogram_min                                       2113.0   93.564600
# histogram_max                                       2113.0  164.099858
# histogram_number_of_peaks                           2113.0    4.077142
# histogram_number_of_zeroes                          2113.0    0.325603
# histogram_mode                                      2113.0  137.454330
# histogram_mean                                      2113.0  134.599621
# histogram_median                                    2113.0  138.089446
# histogram_variance                                  2113.0   18.907241
# histogram_tendency                                  2113.0    0.318504
# fetal_health                                        2113.0    1.303833
#
#                                                           std    min      25%  \
# baseline value                                       9.837451  106.0  126.000
# accelerations                                        0.003871    0.0    0.000
# fetal_movement                                       0.046804    0.0    0.000
# uterine_contractions                                 0.002941    0.0    0.002
# light_decelerations                                  0.002966    0.0    0.000
# severe_decelerations                                 0.000057    0.0    0.000
# prolongued_decelerations                             0.000592    0.0    0.000
# abnormal_short_term_variability                     17.177782   12.0   32.000
# mean_value_of_short_term_variability                 0.884368    0.2    0.700
# percentage_of_time_with_abnormal_long_term_vari...  18.337073    0.0    0.000
# mean_value_of_long_term_variability                  5.632912    0.0    4.600
# histogram_width                                     39.007706    3.0   37.000
# histogram_min                                       29.562269   50.0   67.000
# histogram_max                                       17.945175  122.0  152.000
# histogram_number_of_peaks                            2.951664    0.0    2.000
# histogram_number_of_zeroes                           0.707771    0.0    0.000
# histogram_mode                                      16.402026   60.0  129.000
# histogram_mean                                      15.610422   73.0  125.000
# histogram_median                                    14.478957   77.0  129.000
# histogram_variance                                  29.038766    0.0    2.000
# histogram_tendency                                   0.611075   -1.0    0.000
# fetal_health                                         0.614279    1.0    1.000
#
#                                                         50%      75%      max
# baseline value                                      133.000  140.000  160.000
# accelerations                                         0.002    0.006    0.019
# fetal_movement                                        0.000    0.003    0.481
# uterine_contractions                                  0.005    0.007    0.015
# light_decelerations                                   0.000    0.003    0.015
# severe_decelerations                                  0.000    0.000    0.001
# prolongued_decelerations                              0.000    0.000    0.005
# abnormal_short_term_variability                      49.000   61.000   87.000
# mean_value_of_short_term_variability                  1.200    1.700    7.000
# percentage_of_time_with_abnormal_long_term_vari...    0.000   11.000   91.000
# mean_value_of_long_term_variability                   7.400   10.800   50.700
# histogram_width                                      68.000  100.000  180.000
# histogram_min                                        93.000  120.000  159.000
# histogram_max                                       162.000  174.000  238.000
# histogram_number_of_peaks                             4.000    6.000   18.000
# histogram_number_of_zeroes                            0.000    0.000   10.000
# histogram_mode                                      139.000  148.000  187.000
# histogram_mean                                      136.000  145.000  182.000
# histogram_median                                    139.000  148.000  186.000
# histogram_variance                                    7.000   24.000  269.000
# histogram_tendency                                    0.000    1.000    1.000
# fetal_health                                          1.000    1.000    3.000

# %%
negative_values_found = False
for column in data.select_dtypes(include=['number']).columns:
    negative_count = (data[column] < 0).sum()
    if negative_count > 0:
        print(f"Cột '{column}' có {negative_count} giá trị nhỏ hơn 0.")
        negative_values_found = True

if not negative_values_found:
    print("Không tìm thấy giá trị nào nhỏ hơn 0 trong các cột số.")
# Out:
# Cột 'histogram_tendency' có 165 giá trị nhỏ hơn 0.

# %%
data["histogram_tendency"].value_counts()
# Out:
# histogram_tendency
#  0.0    1110
#  1.0     838
# -1.0     165
# Name: count, dtype: int64

# %%
data["fetal_health"].value_counts()
# Out:
# fetal_health
# 1.0    1646
# 2.0     292
# 3.0     175
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

# Tách X, y
X = data.drop('fetal_health', axis=1)
y = data['fetal_health']

# Chỉ lấy các cột số
num_cols = X.select_dtypes(include=['int64', 'float64']).columns

# Tính Z-score trên toàn bộ X
z_scores = np.abs(zscore(X[num_cols], nan_policy='omit'))

# Chuyển thành DataFrame để giữ index
z_scores = pd.DataFrame(z_scores, columns=num_cols, index=X.index)

# Ngưỡng lọc outlier
threshold = 3.5

# Giữ lại các dòng không chứa outlier
mask = (z_scores < threshold).all(axis=1)

X_clean = X.loc[mask].copy()
y_clean = y.loc[mask].copy()

print(f"Kích thước X trước khi lọc Z-score: {X.shape}")
print(f"Kích thước y trước khi lọc Z-score: {y.shape}")
print(f"Kích thước X sau khi lọc Z-score: {X_clean.shape}")
print(f"Kích thước y sau khi lọc Z-score: {y_clean.shape}")

# Chia train/test sau khi đã lọc
X_train, X_test, y_train, y_test = train_test_split(
    X_clean, y_clean,
    test_size=0.2,
    random_state=42,
    stratify=y_clean
)

print(f"Kích thước tập huấn luyện X: {X_train.shape}")
print(f"Kích thước tập kiểm tra X: {X_test.shape}")
print(f"Kích thước tập huấn luyện y: {y_train.shape}")
print(f"Kích thước tập kiểm tra y: {y_test.shape}")
# Out:
# Kích thước X trước khi lọc Z-score: (2113, 21)
# Kích thước y trước khi lọc Z-score: (2113,)
# Kích thước X sau khi lọc Z-score: (1920, 21)
# Kích thước y sau khi lọc Z-score: (1920,)
# Kích thước tập huấn luyện X: (1536, 21)
# Kích thước tập kiểm tra X: (384, 21)
# Kích thước tập huấn luyện y: (1536,)
# Kích thước tập kiểm tra y: (384,)

# %%
# from sklearn.preprocessing import StandardScaler

# # Khởi tạo scaler
# scaler = StandardScaler()

# # Fit trên tập train, transform cả train và test
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# # Nếu muốn giữ dạng DataFrame để dễ nhìn tên cột
# X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
# X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# print("Đã scale dữ liệu xong")
# display(X_train_scaled.head())

# %%
from sklearn.preprocessing import MinMaxScaler

# Khởi tạo scaler
scaler = MinMaxScaler()

# Fit trên train, transform cả train và test
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Nếu muốn giữ DataFrame
import pandas as pd
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
print("Đã scale dữ liệu xong")
display(X_train_scaled.head())
# Out:
# Đã scale dữ liệu xong
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 568         0.407407         0.5625        0.000000              0.500000
# 1489        0.444444         0.2500        0.000000              0.571429
# 1267        0.166667         0.8125        0.000000              0.142857
# 1845        0.592593         1.0000        0.000000              0.357143
# 750         0.444444         0.0000        0.014388              0.000000
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# 568              0.166667                   0.0                       0.0
# 1489             0.083333                   0.0                       0.0
# 1267             0.000000                   0.0                       0.0
# 1845             0.000000                   0.0                       0.0
# 750              0.000000                   0.0                       0.0
#
#       abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 568                          0.333333                              0.928571
# 1489                         0.373333                              0.166667
# 1267                         0.093333                              0.380952
# 1845                         0.520000                              0.166667
# 750                          0.626667                              0.047619
#
#       percentage_of_time_with_abnormal_long_term_variability  ...  \
# 568                                            0.000000       ...
# 1489                                           0.232877       ...
# 1267                                           0.000000       ...
# 1845                                           0.000000       ...
# 750                                            0.506849       ...
#
#       histogram_width  histogram_min  histogram_max  \
# 568          0.903226       0.018349       0.846154
# 1489         0.245161       0.550459       0.362637
# 1267         0.316129       0.467890       0.384615
# 1845         0.270968       0.660550       0.538462
# 750          0.090323       0.688073       0.263736
#
#       histogram_number_of_peaks  histogram_number_of_zeroes  histogram_mode  \
# 568                    0.500000                         0.5            0.47
# 1489                   0.428571                         0.0            0.50
# 1267                   0.071429                         0.5            0.34
# 1845                   0.214286                         0.0            0.61
# 750                    0.142857                         0.0            0.43
#
#       histogram_mean  histogram_median  histogram_variance  histogram_tendency
# 568         0.656863          0.505376            0.840336                 0.5
# 1489        0.519608          0.451613            0.033613                 0.5
# 1267        0.401961          0.301075            0.075630                 0.5
# 1845        0.676471          0.612903            0.050420                 0.5
# 750         0.509804          0.419355            0.016807                 0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, recall_score

# Khởi tạo model
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

# Train model với dữ liệu đã scale
rf_model.fit(X_train_scaled, y_train)

# Predict
y_pred = rf_model.predict(X_test_scaled)

# Đánh giá
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision weighted:", precision_score(y_test, y_pred, average='weighted'))
print("Recall weighted:", recall_score(y_test, y_pred, average='weighted'))
print("F1 weighted:", f1_score(y_test, y_pred, average='weighted'))

print("Precision macro:", precision_score(y_test, y_pred, average='macro'))
print("Recall macro:", recall_score(y_test, y_pred, average='macro'))
print("F1 macro:", f1_score(y_test, y_pred, average='macro'))
print("\nDetail about one class:")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.953125
# Precision weighted: 0.952054874296765
# Recall weighted: 0.953125
# F1 weighted: 0.9521193456769425
# Precision macro: 0.8949507735583685
# Recall macro: 0.8850684968521171
# F1 macro: 0.8888659613585136
#
# Detail about one class:
# Classification Report:
#                precision    recall  f1-score   support
#
#          1.0       0.97      0.99      0.98       311
#          2.0       0.88      0.79      0.83        56
#          3.0       0.83      0.88      0.86        17
#
#     accuracy                           0.95       384
#    macro avg       0.89      0.89      0.89       384
# weighted avg       0.95      0.95      0.95       384
#
#
# Confusion Matrix:
#  [[307   4   0]
#  [  9  44   3]
#  [  0   2  15]]

# %% [markdown]
# XGBoot

# %%
y_train = y_train.astype(int) - 1
y_test = y_test.astype(int) - 1

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, recall_score

# Khởi tạo model XGBoost
xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softmax',   # dùng cho phân loại nhiều lớp
    num_class=len(y_train.unique()),
    random_state=42,
    n_jobs=-1,
    eval_metric='mlogloss'
)

# Train model
xgb_model.fit(X_train_scaled, y_train)

# Predict
y_pred_xg = xgb_model.predict(X_test_scaled)

# Đánh giá
print("Accuracy:", accuracy_score(y_test, y_pred_xg))
print("Precision weighted:", precision_score(y_test, y_pred_xg, average='weighted'))
print("Recall weighted:", recall_score(y_test, y_pred_xg, average='weighted'))
print("F1 weighted:", f1_score(y_test, y_pred_xg, average='weighted'))

print("Precision macro:", precision_score(y_test, y_pred_xg, average='macro'))
print("Recall macro:", recall_score(y_test, y_pred_xg, average='macro'))
print("F1 macro:", f1_score(y_test, y_pred_xg, average='macro'))

print("\nDetail about one class:")
print("Classification Report:\n", classification_report(y_test, y_pred_xg))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_xg))
# Out:
# Accuracy: 0.9635416666666666
# Precision weighted: 0.9637410996835443
# Recall weighted: 0.9635416666666666
# F1 weighted: 0.9625703638861532
# Precision macro: 0.9207278481012658
# Recall macro: 0.9313083754402083
# F1 macro: 0.9222532248848038
#
# Detail about one class:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       311
#            1       0.94      0.80      0.87        56
#            2       0.85      1.00      0.92        17
#
#     accuracy                           0.96       384
#    macro avg       0.92      0.93      0.92       384
# weighted avg       0.96      0.96      0.96       384
#
#
# Confusion Matrix:
#  [[308   3   0]
#  [  8  45   3]
#  [  0   0  17]]

# %% [markdown]
# Biểu đồ dữ liệu

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# =============================
# 1. Biểu đồ số lượng mẫu trước và sau Z-score
# =============================

before_count = X.shape[0]
after_count = X_clean.shape[0]
removed_count = before_count - after_count

sample_counts = pd.Series({
    "Trước Z-score": before_count,
    "Sau Z-score": after_count,
    "Bị loại": removed_count
})

plt.figure(figsize=(7, 5))
bars = plt.bar(sample_counts.index, sample_counts.values)

plt.title("Số lượng mẫu trước và sau khi xử lý Z-score")
plt.xlabel("Trạng thái dữ liệu")
plt.ylabel("Số lượng mẫu")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        str(int(height)),
        ha='center',
        va='bottom'
    )

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# =============================
# Biểu đồ phân bố 3 lớp sau Z-score
# =============================

class_after_zscore = y_clean.value_counts().sort_index()

plt.figure(figsize=(7, 5))
bars = plt.bar(class_after_zscore.index.astype(str), class_after_zscore.values)

plt.title("Phân bố 3 lớp fetal_health sau khi xử lý Z-score")
plt.xlabel("Lớp fetal_health")
plt.ylabel("Số lượng mẫu")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        str(int(height)),
        ha='center',
        va='bottom'
    )

plt.tight_layout()
plt.show()
